# %% [markdown]
# # Baseline Model Results
#
# This notebook displays the evaluation results for the logistic regression baseline model trained on the SECOM semiconductor manufacturing dataset. The model uses `class_weight="balanced"` to handle the ~6.6% fail-rate class imbalance and is evaluated on a held-out 20% stratified test split. All artifacts (metrics JSON, figures, feature importance CSV) are pre-computed by the pipeline scripts and loaded here for display only.

# %%
import json
from pathlib import Path

metrics = json.loads(Path('../reports/baseline_metrics.json').read_text())
print(f"ROC AUC:   {metrics['roc_auc']:.3f}")
print(f"PR AUC:    {metrics['pr_auc']:.3f}")
print(f"Precision: {metrics['precision']:.3f}")
print(f"Recall:    {metrics['recall']:.3f}")
print(f"F1 Score:  {metrics['f1']:.3f}")
# Out:
# ROC AUC:   0.656
# PR AUC:    0.160
# Precision: 0.119
# Recall:    0.238
# F1 Score:  0.159

# %% [markdown]
# ## Confusion Matrix

# %%
from IPython.display import Image, display
display(Image('../reports/figures/confusion_matrix.png'))

# %% [markdown]
# ## ROC Curve

# %%
display(Image('../reports/figures/roc_curve.png'))

# %% [markdown]
# ## Precision-Recall Curve

# %%
display(Image('../reports/figures/precision_recall_curve.png'))

# %% [markdown]
# ## Feature Importance (Top 20)

# %%
import pandas as pd

importance_df = pd.read_csv('../reports/feature_importance.csv')
display(importance_df.head(20))
display(Image('../reports/figures/feature_importance.png'))
# Out:
#        feature  coefficient  abs_coefficient
# 0   sensor_151    -2.193362         2.193362
# 1   sensor_205     2.154402         2.154402
# 2   sensor_164    -2.150317         2.150317
# 3   sensor_197     1.659449         1.659449
# 4   sensor_523    -1.530926         1.530926
# 5   sensor_059     1.515706         1.515706
# 6   sensor_155    -1.362073         1.362073
# 7   sensor_025     1.360444         1.360444
# 8   sensor_045     1.251715         1.251715
# 9   sensor_035    -1.242905         1.242905
# 10  sensor_196    -1.167619         1.167619
# 11  sensor_014    -1.166411         1.166411
# 12  sensor_573    -1.035812         1.035812
# 13  sensor_026    -1.032659         1.032659
# 14  sensor_041    -0.992272         0.992272
# 15  sensor_061     0.968909         0.968909
# 16  sensor_067    -0.939750         0.939750
# 17  sensor_064     0.921807         0.921807
# 18  sensor_177    -0.887877         0.887877
# 19  sensor_473     0.884100         0.884100
